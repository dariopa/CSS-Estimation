# %%
import os
import numpy as np
from sklearn.utils import shuffle
from PIL import Image


call_folder = '/home/dario/Documents/SemThes_Local/Data_MNIST'

batch_size = 256

X_train = np.load(os.path.join(call_folder, 'X_train.npy'))
y_train = np.load(os.path.join(call_folder, 'y_binned_train.npy'))
print('Shape of X_train:  ', X_train.shape)
print(X_train)

row, col = np.array(Image.open(str(X_train[0]))).shape

for i in range(0, int(np.floor(len(X_train)/batch_size)) + 1):
    if i == (int(np.floor(len(X_train)/batch_size))):
        batch_size = len(X_train) - (i * batch_size)

    X = np.full((batch_size, row, col, 1), 0, dtype = np.uint8)
    
    for k in range(0, batch_size):
        X[k, :, :, 0] = np.array(Image.open(str(X_train[k + i * batch_size])))
    y = y_train[i * batch_size:(i + 1) * batch_size]
# Out:
# Shape of X_train:   (50000,)
# ['/home/dario/Documents/SemThes_Local/Data_MNIST/Images/1.jpg'
#  '/home/dario/Documents/SemThes_Local/Data_MNIST/Images/2.jpg'
#  '/home/dario/Documents/SemThes_Local/Data_MNIST/Images/3.jpg' ...
#  '/home/dario/Documents/SemThes_Local/Data_MNIST/Images/49998.jpg'
#  '/home/dario/Documents/SemThes_Local/Data_MNIST/Images/49999.jpg'
#  '/home/dario/Documents/SemThes_Local/Data_MNIST/Images/50000.jpg']

# %%
import os
import numpy as np
from sklearn.utils import shuffle
from PIL import Image

def batch_generator(X, y, batch_size):

    row, col = np.array(Image.open(str(X[0]))).shape

    if i == (int(np.floor(len(X) / batch_size))):
        batch_size = len(X) - (i * batch_size)

    X_send = np.full((batch_size, row, col, 1), 0, dtype = np.uint8)

    for k in range(0, batch_size):
        X_send[k, :, :, 0] = np.array(Image.open(str(X[k + i * batch_size])))

    y_send = y[i * batch_size:(i + 1) * batch_size]

    (X_send, y_send) = shuffle(X_send, y_send)
    ,# print(len(X_send))
    return(X_send, y_send)
        
def batch_generator_V2(X, y, batch_size):
       
    for i in range(0, X.shape[0], batch_size):
        yield (X[i:i+batch_size, :], y[i:i+batch_size])

# %%
for i in range(0, int(np.floor(len(X_train) / batch_size)) + 1):
    batch_x, batch_y = batch_generator(X_train, y_train, batch_size)
# Out:
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 0

# %%
batch_size = 2

X = np.random.rand(10,2)
y = np.random.rand(10,1)
for i in range(0, X.shape[0], batch_size):
    print(X[i:i+batch_size, :])
    print(y[i:i+batch_size])
        
print()
batch_gen = batch_generator_V2(X, y, batch_size)
for i, (batch_x, batch_y) in enumerate(batch_gen):
    print(batch_x)
    print()
    print(batch_y)
    print()
    print()
# Out:
# [[0.9931468  0.28616305]
#  [0.46326268 0.96539933]]
# [[0.42819483]
#  [0.99984705]]
# [[0.65770544 0.5325134 ]
#  [0.72421216 0.20555656]]
# [[0.87075005]
#  [0.25124616]]
# [[0.54886465 0.83124978]
#  [0.90058667 0.13235013]]
# [[0.76100273]
#  [0.25671635]]
# [[0.01219723 0.216579  ]
#  [0.7745061  0.07256572]]
# [[0.23765432]
#  [0.02808648]]
# [[0.70423324 0.09983454]
#  [0.46068519 0.71651411]]
# [[0.0941361 ]
#  [0.31899304]]
#
# [[0.9931468  0.28616305]
#  [0.46326268 0.96539933]]
#
# [[0.42819483]
#  [0.99984705]]
#
#
# [[0.65770544 0.5325134 ]
#  [0.72421216 0.20555656]]
#
# [[0.87075005]
#  [0.25124616]]
#
#
# [[0.54886465 0.83124978]
#  [0.90058667 0.13235013]]
#
# [[0.76100273]
#  [0.25671635]]
#
#
# [[0.01219723 0.216579  ]
#  [0.7745061  0.07256572]]
#
# [[0.23765432]
#  [0.02808648]]
#
#
# [[0.70423324 0.09983454]
#  [0.46068519 0.71651411]]
#
# [[0.0941361 ]
#  [0.31899304]]

# %%
X = np.random.rand(10,2)
y = np.random.rand(10,1)

np.save('bla.npy', X)
np.save('blabla.npy', y)
